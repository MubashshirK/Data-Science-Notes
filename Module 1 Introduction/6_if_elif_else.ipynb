# %% [markdown]
# # **Python if... else Statement**
#
# The **if...elif...else** statement is used in Python for decision making.

# %% [markdown]
# ## **if statement syntax**
#
#     if test expression:
#
#         statement(s)

# %% [markdown]
# The program evaluates the test expression and will execute statement(s) only if the text expression is True.
#
# If the text expression is False, the statement(s) is not executed.
#
# Python interprets non-zero values as True. None and 0 are interpreted as False.

# %% [markdown]
# ## **Flow Chart**

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://www.datamentor.io/sites/tutorial2program/files/r-if-statement.jpg">
# </div>

# %% [markdown]
# ## **Example**

# %%
num = 10

# try 0, -1 and None
if num > 10:
    print("Number is positive")
print("This will print always")            #This print statement always prints

#change number
# Out:
# This will print always

# %% [markdown]
# ## **if ... else Statement**
#
# ## **Syntax**:
#
#     if test expression:
#
#         Body of if
#
#     else:
#         Body of else

# %% [markdown]
# ## **Flow Chart**

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://www.datamentor.io/sites/tutorial2program/files/r-if-else-statement.jpg">
# </div>

# %% [markdown]
# ## **Example**

# %%
num = 10

if num > 0:
    print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %% [markdown]
# ## **if..elif..else statement**
#
# ## **Syntax**
#
#     if test expression:
#         Body of if
#
#     elif test expression:
#         Body of elif
#
#     else:
#         Body of else

# %% [markdown]
# ## **Flow Chart**

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://dphi-live.s3.amazonaws.com/media_uploads/image_04b0e7f26ae541f2a2a57d93a3c9743c.png">
# </div>

# %% [markdown]
# ## **Example**

# %%
num = 10.5

if num > 0:
    print("Postivie Number")
elif num == 0:
    print("ZERO")
else:
    print("Negative Number")
# Out:
# Postivie Number

# %% [markdown]
# ## **Nested if Statements**
#
# We can have if...elif...else statement inside another if...elif...else statement. This is called nested in computer programming.

# %% [markdown]
# ## **Example**

# %%
num = 10.5

if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %% [markdown]
# ## **Python program to find the largest element among three Numbers**

# %%
num1 = 10
num2 = 50
num3 = 15

if (num1 >= num2) and (num1 >= num3):                #logical operator AND
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
print("Largest element among three numbers is {}".format(largest))
# Out:
# Largest element among three numbers is 50
