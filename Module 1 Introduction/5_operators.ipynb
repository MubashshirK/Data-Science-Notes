# %% [markdown]
# # **Operators**
#
# Operators are special symbols in Python that carry out arithmetic or logical computation.<br> The value that the operator operates on is called operand.

# %% [markdown]
# # **Operator Types**
#
# 1. Arithmetic operators
# 2. Comparison (Relational) operators
# 3. Logical (Boolean) operators
# 4. Bitwise operators
# 5. Assignment operators
# 6. Special operators

# %% [markdown]
# ## **Arithmetic Operators**
#
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, etc.

# %% [markdown]
# > \+ , - , * , / , % , // , **  are arithmetic operators

# %% [markdown]
# Example:

# %%
x, y = 10, 20

# Addition
print(x + y)

# Subtraction(-)
print(x - y)

# Multiplication(*)
print(x * y)

# Division(/)
print(x / y)

# Modulo Division (%)
print(x % y)

#Floor Division (//)
print(x // y)

# Exponent (**)
print(x ** y)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 0
# 100000000000000000000

# %% [markdown]
# ## **Comparision Operators**
#
# Comparison operators are used to compare values. It either returns True or False according to the condition.

# %% [markdown]
# > \>, <, ==, !=, >=, <= are comparision operators

# %%
a, b = 10, 20

print(a < b)    #check a is less than b

#check a is greater than b
print(a > b)

#check a is equal to b
print(a == b)

#check a is not equal to b (!=)
print(a != b)

#check a is greater than or equal to b
print(a >= b)

#check a is less than or equal to b
print(a <= b)
# Out:
# True
# False
# False
# True
# False
# True

# %% [markdown]
# ## **Logical Operators**
#
# Logical operators are **and, or, not** operators

# %%
a, b = True, False

#print a and b
print(a and b)

#print a or b
print(a or b)

#print not b
print(not b)
# Out:
# False
# True
# True

# %% [markdown]
# ## **Bitwise Operators**
#
# Bitwise operators act on operands as if they were string of binary digits. It operates bit by bit.

# %% [markdown]
# > & , | , - , ^ , >> , << are Bitwise operators

# %%
a, b = 10, 4

#Bitwise AND
print(a & b)

#Bitwise OR
print(a | b)

#Bitwise NOT
print(a - b)

#Bitwise XOR
print(a ^ b)

#Bitwise Rightshift
print(a >> b)

#Bitwise Leftshift
print(a << b)
# Out:
# 0
# 14
# 6
# 14
# 0
# 160

# %% [markdown]
# ## **Assignment Operators**
#
# Assignment operators are used in Python to assign values to variables.
#
# a = 5 is a simple assignment operator that assigns the value 5 on the right to the variable a on the left.

# %% [markdown]
# > = , += , -= , *= , /= , %= , //= , **= , &= , |= , ^= , >>= , <<= are Assignment operators

# %%
a = 10

a += 10        #add AND
print(a)

#subtract AND (-=)
a -= 10
print(a)

#Multiple AND (*=)
a *= 10
print(a)

#Divide AND (/=)
a /= 10
print(a)

#Modulus AND (%=)
a %= 10
print(a)

#Floor Division (//=)
a //= 10
print(a)

#Exponent AND (**=)
a **= 10
print(a)
# Out:
# 20
# 10
# 100
# 10.0
# 0.0
# 0.0
# 0.0

# %% [markdown]
# ## **Special Operators**

# %% [markdown]
# ## **Identity Operators**
#
# **is and is not** are the identity operators in Python.
#
# They are used to check if two values (or variables) are located on the same part of the memory.

# %%
a = 5
b = 5

print(a is b)    #5 is objecct created once both a and b points to same object

#check is not
print(a is not b)
# Out:
# True
# False

# %%
l1 = [1, 2, 3]
l2 = [1, 2, 3]

print(l1 is l2)
# Out:
# False

# %%
s1 = "AAIC"
s2 = "AAIC"

print(s1 is not s2)
# Out:
# False

# %% [markdown]
# ## **MemberShip Operators**
#
# **in and not in** are the membership operators in Python.
#
# They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).

# %%
lst = [1, 2, 3, 4]
print(1 in lst)        #check 1 is present in the given list or not

#check if 5 is present in the given list
print( 5 in lst)
# Out:
# True
# False

# %%
d = {1: "a", 2: "b"}        #this is a dictionary
print(1 in d)               #only checks for keys in the dictionary
# Out:
# True
